# %%
from transformers import pipeline

pipe = pipeline("text-generation", model="LGAI-EXAONE/EXAONE-4.0-1.2B")
messages = [
    {"role": "user", "content": "Who are you?"},
]
pipe(messages)
# Out:
# Device set to use cpu
# [{'generated_text': [{'role': 'user', 'content': 'Who are you?'},
#    {'role': 'assistant',
#     'content': 'I am EXAONE, developed by LG AI Research. As an artificial intelligence assistant, my purpose is to learn and provide user support using advanced language models.'}]}]
