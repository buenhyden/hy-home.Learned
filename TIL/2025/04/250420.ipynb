# %%
import os

# 루트 경로 지정 (변경 가능)
root_dir = r"D:\blog-data\content\posts2\AI"

# 디렉토리 구조 정의 (파일은 무시하고 폴더만)
dirs = [
    "",  # root: AI/
    "Fundamentals",
    "Fundamentals/AI-Basics",
    "Fundamentals/Machine-Learning-Basics",
    "Fundamentals/Neural-Networks-Basics",
    "Machine Learning",
    "Machine Learning/Algorithms",
    "Machine Learning/Algorithms/Classification",
    "Machine Learning/Algorithms/Regression",
    "Machine Learning/Algorithms/Clustering",
    "Machine Learning/Model-Evaluation",
    "Machine Learning/Model-Evaluation/Metrics",
    "Machine Learning/Feature-Engineering",
    "Deep Learning",
    "Deep Learning/Neural-Network-Types",
    "Deep Learning/Neural-Network-Types/CNNs",
    "Deep Learning/Neural-Network-Types/RNNs-and-LSTMs",
    "Deep Learning/Neural-Network-Types/Transformers",
    "Deep Learning/Training-Techniques",
    "Deep Learning/Self-Supervised-Learning",
    "Deep Learning/Model-Compression",
    "Foundation Models",
    "Foundation Models/Large-Language-Models",
    "Foundation Models/Vision-Models",
    "Foundation Models/Fine-Tuning-Methods",
    "Foundation Models/Model-Evaluation",
    "Natural Language Processing",
    "Natural Language Processing/Text-Processing",
    "Natural Language Processing/Language-Models",
    "Natural Language Processing/NLP-Tasks",
    "Natural Language Processing/Vector-Representations",
    "Computer Vision",
    "Computer Vision/Image-Processing",
    "Computer Vision/Vision-Tasks",
    "Computer Vision/Advanced-Topics",
    "Generative AI",
    "Generative AI/Text-Generation",
    "Generative AI/Image-Generation",
    "Generative AI/Image-Generation/GANs",
    "Generative AI/Image-Generation/Diffusion-Models",
    "Generative AI/Audio-Generation",
    "Multimodal AI",
    "Multimodal AI/Vision-Language-Models",
    "Multimodal AI/Text-to-Image",
    "Multimodal AI/Multimodal-Applications",
    "LLM Engineering",
    "LLM Engineering/Prompt-Engineering",
    "LLM Engineering/RAG-Systems",
    "LLM Engineering/LLM-Applications",
    "LLM Engineering/Evaluation",
    "MLOps",
    "MLOps/Model-Development",
    "MLOps/Model-Deployment",
    "MLOps/Model-Monitoring",
    "MLOps/Feature-Stores",
    "AI Ethics and Governance",
    "AI Ethics and Governance/Bias-and-Fairness",
    "AI Ethics and Governance/Explainability",
    "AI Ethics and Governance/Privacy",
    "AI Ethics and Governance/Regulatory-Frameworks",
    "AI Agents",
    "AI Agents/Agent-Architectures",
    "AI Agents/Reinforcement-Learning",
    "AI Agents/Multi-Agent-Systems",
    "Industry Applications",
    "Industry Applications/Healthcare",
    "Industry Applications/Finance",
    "Industry Applications/Manufacturing",
    "Industry Applications/Retail",
]

# 폴더 생성
for path in dirs:
    full_path = os.path.join(root_dir, path)
    os.makedirs(full_path, exist_ok=True)
print("✅ 모든 폴더가 성공적으로 생성되었습니다.")
# Out:
# ✅ 모든 폴더가 성공적으로 생성되었습니다.

# %%
import os

# 루트 디렉토리 설정 (원하는 경로로 수정)
root_path = r"D:\blog-data\content\posts2\Backend"

# 생성할 폴더 경로 목록
folders = [
    "",
    "Fundamentals",
    "Fundamentals/Backend-Basics",
    "Fundamentals/Communication-Protocols",
    "Fundamentals/Data-Exchange",
    "API Design",
    "API Design/API-Fundamentals",
    "API Design/API-Styles",
    "API Design/API-Styles/REST",
    "API Design/API-Styles/GraphQL",
    "API Design/API-Styles/gRPC",
    "API Design/API-Styles/SOAP",
    "API Design/API-Implementation",
    "API Design/API-Documentation",
    "API Design/API-Security",
    "API Design/API-Testing",
    "Backend Architecture",
    "Backend Architecture/Monolithic",
    "Backend Architecture/Microservices",
    "Backend Architecture/Microservices/Microservices-Patterns",
    "Backend Architecture/Serverless",
    "Backend Architecture/Backend-for-Frontend",
    "Backend Architecture/Layered-Architecture",
    "Event and Message Brokers",
    "Event and Message Brokers/Message-Queue-Fundamentals",
    "Event and Message Brokers/Event-Driven-Architecture",
    "Event and Message Brokers/Message-Broker-Systems",
    "Event and Message Brokers/Message-Broker-Systems/Apache-Kafka",
    "Event and Message Brokers/Message-Broker-Systems/RabbitMQ",
    "Event and Message Brokers/Message-Broker-Systems/Redis-Pub-Sub",
    "Event and Message Brokers/Event-Processing",
    "Performance Optimization",
    "Performance Optimization/Caching",
    "Performance Optimization/Caching/Cache-Strategies",
    "Performance Optimization/Caching/Cache-Systems",
    "Performance Optimization/Database-Optimization",
    "Performance Optimization/Asynchronous-Processing",
    "Performance Optimization/Load-Balancing",
    "Web Infrastructure",
    "Web Infrastructure/Web-Servers",
    "Web Infrastructure/Web-Servers/Nginx",
    "Web Infrastructure/Web-Servers/Apache",
    "Web Infrastructure/Reverse-Proxy",
    "Web Infrastructure/DNS",
    "Web Infrastructure/CDN",
    "Search Engines",
    "Search Engines/Search-Fundamentals",
    "Search Engines/Elasticsearch",
    "Search Engines/Solr",
    "Search Engines/Vector-Search",
    "Observability",
    "Observability/Logging",
    "Observability/Metrics",
    "Observability/Tracing",
    "Observability/Health-Checks",
]

# 폴더 생성
for folder in folders:
    dir_path = os.path.join(root_path, folder)
    os.makedirs(dir_path, exist_ok=True)

print("✅ 모든 폴더가 성공적으로 생성되었습니다.")
# Out:
# ✅ 모든 폴더가 성공적으로 생성되었습니다.

# %%
import os

# 최상위 루트 경로 (필요에 따라 수정 가능)
root_path = r"D:\blog-data\content\posts2\Cloud and DevOps"

# 생성할 폴더 목록
folders = [
    "",
    "Fundamentals",
    "Fundamentals/Cloud-Computing-Basics",
    "Fundamentals/DevOps-Basics",
    "Fundamentals/Infrastructure-Basics",
    "Cloud Native",
    "Cloud Native/Containerization",
    "Cloud Native/Containerization/Docker",
    "Cloud Native/Kubernetes",
    "Cloud Native/Kubernetes/Core-Components",
    "Cloud Native/Kubernetes/Networking",
    "Cloud Native/Kubernetes/Resource-Management",
    "Cloud Native/Service Mesh",
    "Cloud Native/Service Mesh/Istio",
    "Cloud Native/Serverless",
    "CI and CD",
    "CI and CD/CI-CD-Fundamentals",
    "CI and CD/Deployment-Strategies",
    "CI and CD/Tools",
    "Infrastructure as Code",
    "Infrastructure as Code/Configuration-Management",
    "Infrastructure as Code/Infrastructure-Provisioning",
    "Infrastructure as Code/Infrastructure-Provisioning/Terraform",
    "Infrastructure as Code/Policy-as-Code",
    "Cloud Providers",
    "Cloud Providers/AWS",
    "Cloud Providers/AWS/Core-Services",
    "Cloud Providers/AWS/Networking",
    "Cloud Providers/Azure",
    "Cloud Providers/Azure/Core-Services",
    "Cloud Providers/GCP",
    "Cloud Providers/GCP/Core-Services",
    "Monitoring and Observability",
    "Monitoring and Observability/Logging",
    "Monitoring and Observability/Metrics",
    "Monitoring and Observability/Tracing",
    "Site Reliability Engineering",
    "Site Reliability Engineering/Chaos-Engineering",
    "Site Reliability Engineering/Incident-Management",
    "Site Reliability Engineering/SLI-SLO-SLA",
    "GitOps",
    "FinOps",
    "AIOps",
    "Multi-cloud Strategy",
    "Version Control Systems",
    "Version Control Systems/Git-Advanced",
    "Version Control Systems/Git-Basics",
]

# 폴더 생성
for folder in folders:
    dir_path = os.path.join(root_path, folder)
    os.makedirs(dir_path, exist_ok=True)

print("✅ Cloud and DevOps 카테고리 폴더 구조가 모두 생성되었습니다.")
# Out:
# ✅ Cloud and DevOps 카테고리 폴더 구조가 모두 생성되었습니다.

# %%
import os

# 최상위 루트 디렉토리 설정 (환경에 따라 수정하세요)
root_path = r"D:\blog-data\content\posts2\Computer Science"

# 폴더 구조 정의 (.md 파일 제외)
folders = [
    "",
    "Fundamentals",
    "Fundamentals/Computational-Concepts",
    "Fundamentals/Discrete-Mathematics",
    "Fundamentals/Binary-Representation",
    "Fundamentals/Programming-Paradigms",
    "Computer Architecture",
    "Computer Architecture/Computer-Organization",
    "Computer Architecture/Processor-Architecture",
    "Computer Architecture/Memory-Systems",
    "Computer Architecture/Input-Output-Systems",
    "Operating Systems",
    "Operating Systems/OS-Concepts",
    "Operating Systems/Process-Management",
    "Operating Systems/Thread-Management",
    "Operating Systems/Memory-Management",
    "Operating Systems/File-Systems",
    "Operating Systems/Concurrency",
    "Theoretical Foundations",
    "Theoretical Foundations/Automata-Theory",
    "Theoretical Foundations/Computability-Theory",
    "Theoretical Foundations/Computational-Complexity",
    "Theoretical Foundations/Formal-Languages",
    "Performance",
    "Performance/Performance-Fundamentals",
    "Performance/CPU-Performance",
    "Performance/Memory-Performance",
    "Performance/IO-Performance",
]

# 폴더 생성
for folder in folders:
    dir_path = os.path.join(root_path, folder)
    os.makedirs(dir_path, exist_ok=True)

print("✅ Computer Science 카테고리 폴더 구조가 성공적으로 생성되었습니다.")
# Out:
# ✅ Computer Science 카테고리 폴더 구조가 성공적으로 생성되었습니다.

# %%
import os

# 루트 경로 설정 (환경에 맞게 수정)
root_path = r"D:\blog-data\content\posts2\Databases"

# 폴더 경로 목록
folders = [
    "",
    "Fundamentals",
    "Fundamentals/Database-Concepts",
    "Fundamentals/Data-Modeling",
    "Fundamentals/Database-Architecture",
    "Fundamentals/Transactions",
    "RDBMS",
    "RDBMS/RDBMS-Concepts",
    "RDBMS/SQL",
    "RDBMS/SQL/SQL-Basics",
    "RDBMS/SQL/SQL-Advanced",
    "RDBMS/SQL/Indexes",
    "RDBMS/SQL/Query-Optimization",
    "RDBMS/PostgreSQL",
    "RDBMS/PostgreSQL/PostgreSQL-Architecture",
    "RDBMS/PostgreSQL/PostgreSQL-Features",
    "RDBMS/PostgreSQL/PostgreSQL-Extensions",
    "RDBMS/PostgreSQL/PostgreSQL-Administration",
    "RDBMS/MySQL",
    "RDBMS/MySQL/MySQL-Architecture",
    "RDBMS/MySQL/MySQL-Features",
    "RDBMS/MySQL/MySQL-Administration",
    "RDBMS/SQL-Server",
    "RDBMS/SQL-Server/SQL-Server-Features",
    "RDBMS/SQL-Server/SQL-Server-Administration",
    "NoSQL",
    "NoSQL/NoSQL-Concepts",
    "NoSQL/Document-Databases",
    "NoSQL/Document-Databases/MongoDB",
    "NoSQL/Document-Databases/Couchbase",
    "NoSQL/Key-Value-Stores",
    "NoSQL/Key-Value-Stores/Redis",
    "NoSQL/Key-Value-Stores/DynamoDB",
    "NoSQL/Column-Family-Stores",
    "NoSQL/Column-Family-Stores/Cassandra",
    "NoSQL/Column-Family-Stores/HBase",
    "NoSQL/Graph-Databases",
    "NoSQL/Graph-Databases/Neo4j",
    "NoSQL/Graph-Databases/ArangoDB",
    "NoSQL/Time-Series-Databases",
    "NoSQL/Time-Series-Databases/InfluxDB",
    "NoSQL/Time-Series-Databases/TimescaleDB",
    "NewSQL",
    "NewSQL/NewSQL-Concepts",
    "NewSQL/CockroachDB",
    "NewSQL/Google-Spanner",
    "NewSQL/SingleStore",
    "Data Warehousing",
    "Data Warehousing/Data-Warehouse-Concepts",
    "Data Warehousing/Snowflake",
    "Data Warehousing/BigQuery",
    "Data Warehousing/Redshift",
    "Database Design",
    "Database Design/Relational-Design",
    "Database Design/NoSQL-Design-Patterns",
    "Database Design/Data-Modeling-Tools",
    "Scaling Databases",
    "Scaling Databases/Scaling-Strategies",
    "Scaling Databases/Replication",
    "Scaling Databases/Sharding",
    "Scaling Databases/Database-Caching",
    "Scaling Databases/Connection-Pooling",
]

# 폴더 생성 실행
for folder in folders:
    dir_path = os.path.join(root_path, folder)
    os.makedirs(dir_path, exist_ok=True)

print("✅ Databases 카테고리 폴더 구조가 성공적으로 생성되었습니다.")
# Out:
# ✅ Databases 카테고리 폴더 구조가 성공적으로 생성되었습니다.

# %%
import os

# 루트 디렉토리 목록 정의
category_roots = {
    "Computer Science": r"D:\blog-data\content\posts2\Computer Science",
    "Data Structures and Algorithms": r"D:\blog-data\content\posts2\Data Structures and Algorithms",
    "Databases": r"D:\blog-data\content\posts2\Databases",
    "Data Engineering": r"D:\blog-data\content\posts2\Data Engineering",
    "Data Science": r"D:\blog-data\content\posts2\Data Science",
}

# 각 카테고리의 상대 경로 목록
category_folders = {
    "Computer Science": [
        "",
        "Fundamentals/Computational-Concepts",
        "Fundamentals/Discrete-Mathematics",
        "Fundamentals/Binary-Representation",
        "Fundamentals/Programming-Paradigms",
        "Computer Architecture/Computer-Organization",
        "Computer Architecture/Processor-Architecture",
        "Computer Architecture/Memory-Systems",
        "Computer Architecture/Input-Output-Systems",
        "Operating Systems/OS-Concepts",
        "Operating Systems/Process-Management",
        "Operating Systems/Thread-Management",
        "Operating Systems/Memory-Management",
        "Operating Systems/File-Systems",
        "Operating Systems/Concurrency",
        "Theoretical Foundations/Automata-Theory",
        "Theoretical Foundations/Computability-Theory",
        "Theoretical Foundations/Computational-Complexity",
        "Theoretical Foundations/Formal-Languages",
        "Performance/Performance-Fundamentals",
        "Performance/CPU-Performance",
        "Performance/Memory-Performance",
        "Performance/IO-Performance",
    ],
    "Data Structures and Algorithms": [
        "",
        "Fundamentals/Algorithm-Basics",
        "Fundamentals/Complexity-Analysis",
        "Fundamentals/Recursion",
        "Fundamentals/Mathematics-for-DSA",
        "Data Structures/Basic-Data-Structures/Arrays",
        "Data Structures/Basic-Data-Structures/Linked-Lists",
        "Data Structures/Basic-Data-Structures/Stacks",
        "Data Structures/Basic-Data-Structures/Queues",
        "Data Structures/Trees/Binary-Trees",
        "Data Structures/Trees/Binary-Search-Trees",
        "Data Structures/Trees/Balanced-Trees",
        "Data Structures/Trees/Advanced-Trees",
        "Data Structures/Hash-Based-Structures/Hash-Tables",
        "Data Structures/Hash-Based-Structures/Bloom-Filters",
        "Data Structures/Hash-Based-Structures/Cuckoo-Hashing",
        "Data Structures/Graph-Data-Structures/Graph-Representations",
        "Data Structures/Graph-Data-Structures/Graph-Types",
        "Data Structures/Graph-Data-Structures/Special-Graphs",
        "Algorithms/Sorting-Algorithms/Comparison-Based-Sorts",
        "Algorithms/Sorting-Algorithms/Non-Comparison-Sorts",
        "Algorithms/Sorting-Algorithms/Sorting-Applications",
        "Algorithms/Searching-Algorithms/Pattern-Matching",
        "Algorithms/Graph-Algorithms/Graph-Traversal",
        "Algorithms/Graph-Algorithms/Shortest-Path-Algorithms",
        "Algorithms/Graph-Algorithms/Minimum-Spanning-Tree",
        "Algorithms/Graph-Algorithms/Graph-Problems",
        "Algorithms/Dynamic-Programming/DP-Principles",
        "Algorithms/Dynamic-Programming/DP-Patterns",
        "Algorithms/Dynamic-Programming/Advanced-DP",
        "Algorithms/Greedy-Algorithms",
        "Problem Solving Techniques/Problem-Solving-Framework",
        "Problem Solving Techniques/Design-Techniques",
        "Problem Solving Techniques/Common-Patterns",
        "Problem Solving Techniques/Advanced-Techniques",
        "Indexing/Indexing-Basics",
        "Indexing/B-Tree-Indexes",
        "Indexing/Hash-Indexes",
        "Indexing/Advanced-Indexing",
    ],
    "Databases": [
        "",
        "Fundamentals/Database-Concepts",
        "Fundamentals/Data-Modeling",
        "Fundamentals/Database-Architecture",
        "Fundamentals/Transactions",
        "RDBMS/RDBMS-Concepts",
        "RDBMS/SQL/SQL-Basics",
        "RDBMS/SQL/SQL-Advanced",
        "RDBMS/SQL/Indexes",
        "RDBMS/SQL/Query-Optimization",
        "RDBMS/PostgreSQL/PostgreSQL-Architecture",
        "RDBMS/PostgreSQL/PostgreSQL-Features",
        "RDBMS/PostgreSQL/PostgreSQL-Extensions",
        "RDBMS/PostgreSQL/PostgreSQL-Administration",
        "RDBMS/MySQL/MySQL-Architecture",
        "RDBMS/MySQL/MySQL-Features",
        "RDBMS/MySQL/MySQL-Administration",
        "RDBMS/SQL-Server/SQL-Server-Features",
        "RDBMS/SQL-Server/SQL-Server-Administration",
        "NoSQL/NoSQL-Concepts",
        "NoSQL/Document-Databases/MongoDB",
        "NoSQL/Document-Databases/Couchbase",
        "NoSQL/Key-Value-Stores/Redis",
        "NoSQL/Key-Value-Stores/DynamoDB",
        "NoSQL/Column-Family-Stores/Cassandra",
        "NoSQL/Column-Family-Stores/HBase",
        "NoSQL/Graph-Databases/Neo4j",
        "NoSQL/Graph-Databases/ArangoDB",
        "NoSQL/Time-Series-Databases/InfluxDB",
        "NoSQL/Time-Series-Databases/TimescaleDB",
        "NewSQL/NewSQL-Concepts",
        "NewSQL/CockroachDB",
        "NewSQL/Google-Spanner",
        "NewSQL/SingleStore",
        "Data Warehousing/Data-Warehouse-Concepts",
        "Data Warehousing/Snowflake",
        "Data Warehousing/BigQuery",
        "Data Warehousing/Redshift",
        "Database Design/Relational-Design",
        "Database Design/NoSQL-Design-Patterns",
        "Database Design/Data-Modeling-Tools",
        "Scaling Databases/Scaling-Strategies",
        "Scaling Databases/Replication",
        "Scaling Databases/Sharding",
        "Scaling Databases/Database-Caching",
        "Scaling Databases/Connection-Pooling",
    ],
    "Data Engineering": [
        "",
        "Fundamentals/Data-Engineering-Basics",
        "Fundamentals/Data-Architectures",
        "Fundamentals/Data-Formats",
        "Fundamentals/Data-Modeling",
        "Data Ingestion Architectures/Batch-Processing",
        "Data Ingestion Architectures/Stream-Processing",
        "Data Ingestion Architectures/Change-Data-Capture",
        "Data Ingestion Architectures/Data-Integration",
        "ETL and ELT Processes/ETL-Fundamentals",
        "ETL and ELT Processes/Extraction",
        "ETL and ELT Processes/Transformation",
        "ETL and ELT Processes/Loading",
        "Data Pipelines/Pipeline-Design",
        "Data Pipelines/Pipeline-Orchestration",
        "Data Pipelines/Pipeline-Monitoring",
        "Data Pipelines/Data-Pipeline-Tools/Apache-Airflow",
        "Big Data Technologies/Hadoop-Ecosystem",
        "Big Data Technologies/Spark",
        "Big Data Technologies/Distributed-Processing",
        "Big Data Technologies/NoSQL-Databases",
        "Data Storage/Storage-Systems",
        "Data Storage/Data-Partitioning",
        "Data Storage/Columnar-Storage",
        "Data Storage/Storage-Optimization",
        "Data Warehousing/Warehouse-Architecture",
        "Data Warehousing/Warehouse-Implementation",
        "Data Warehousing/Cloud-Data-Warehouses",
        "Data Warehousing/OLAP",
        "Real-time Data Processing/Streaming-Concepts",
        "Real-time Data Processing/Messaging-Systems/Apache-Kafka",
        "Real-time Data Processing/Stream-Processing-Frameworks",
        "Real-time Data Processing/Real-time-Analytics",
        "Data Quality and Testing/Data-Quality-Framework",
        "Data Quality and Testing/Data-Validation",
        "Data Quality and Testing/Data-Testing",
        "Data Quality and Testing/Data-Quality-Tools",
        "Data Governance/Governance-Framework",
        "Data Governance/Metadata-Management",
        "Data Governance/Data-Security",
        "Data Governance/Compliance",
        "Cloud Data Platforms/AWS-Data-Services",
        "Cloud Data Platforms/Azure-Data-Services",
        "Cloud Data Platforms/GCP-Data-Services",
        "Cloud Data Platforms/Multi-Cloud-Strategies",
        "Advanced Data Architectures/Data-Mesh",
        "Advanced Data Architectures/Lakehouse-Architecture",
        "Advanced Data Architectures/Modern-Data-Stack",
        "Advanced Data Architectures/DataOps",
    ],
    "Data Science": [
        "",
        "Fundamentals/Data-Science-Basics",
        "Fundamentals/Data-Science-Lifecycle",
        "Fundamentals/Data-Science-Tools",
        "Fundamentals/Data-Science-Ethics",
        "Mathematics/Linear-Algebra",
        "Mathematics/Calculus",
        "Mathematics/Probability",
        "Mathematics/Optimization",
        "Statistics/Descriptive-Statistics",
        "Statistics/Inferential-Statistics",
        "Statistics/Hypothesis-Testing",
        "Statistics/Statistical-Models",
        "Data Collection/Data-Sources",
        "Data Collection/Web-Scraping",
        "Data Collection/API-Integration",
        "Data Collection/Data-Collection-Ethics",
        "Data Cleaning/Data-Quality",
        "Data Cleaning/Preprocessing-Techniques",
        "Data Cleaning/Text-Data-Cleaning",
        "Data Cleaning/Data-Transformation",
        "Exploratory Data Analysis/EDA-Process",
        "Exploratory Data Analysis/Data-Visualization/Visualization-Types",
        "Exploratory Data Analysis/Statistical-Analysis",
        "Exploratory Data Analysis/EDA-Tools",
        "Data Analytics/Business-Intelligence",
        "Data Analytics/Data-Reporting",
        "Data Analytics/Analytical-Techniques",
        "Data Analytics/Analytics-Tools",
        "Statistical Analysis/Regression-Analysis",
        "Statistical Analysis/Time-Series-Analysis",
        "Statistical Analysis/Multivariate-Analysis",
        "Statistical Analysis/Bayesian-Analysis",
        "Econometrics/Econometric-Models",
        "Econometrics/Causal-Inference",
        "Econometrics/Experimental-Design",
        "Econometrics/Economic-Applications",
        "Advanced Topics/Machine-Learning-Integration",
        "Advanced Topics/Big-Data-Analytics",
        "Advanced Topics/Explainable-AI",
        "Advanced Topics/Research-Methods",
    ],
}

# 모든 폴더 생성
for category, root in category_roots.items():
    for rel_path in category_folders[category]:
        abs_path = os.path.join(root, rel_path)
        os.makedirs(abs_path, exist_ok=True)

print("✅ 모든 카테고리의 폴더 구조가 성공적으로 생성되었습니다.")
# Out:
# ✅ 모든 카테고리의 폴더 구조가 성공적으로 생성되었습니다.

# %%
import os

# Emerging Technologies 폴더 구조에서 최상위 카테고리 이름 추출
emerging_technologies_path = r"D:\blog-data\content\posts2\Emerging Technologies"

# 주요 기술 영역 서브 디렉토리
emerging_tech_subfolders = [
    "Blockchain/Blockchain-Fundamentals",
    "Blockchain/Smart-Contracts",
    "Blockchain/DeFi",
    "Blockchain/Web3",
    "Quantum Computing/Quantum-Fundamentals",
    "Quantum Computing/Quantum-Algorithms",
    "Quantum Computing/Quantum-Hardware",
    "Quantum Computing/Quantum-Applications",
    "Extended Reality/Virtual-Reality",
    "Extended Reality/Augmented-Reality",
    "Extended Reality/Mixed-Reality",
    "Extended Reality/Metaverse",
    "IoT/IoT-Fundamentals",
    "IoT/IoT-Implementation",
    "IoT/Industrial-IoT",
    "IoT/IoT-Applications",
    "Edge Computing/Edge-Fundamentals",
    "Edge Computing/Edge-Infrastructure",
    "Edge Computing/Edge-Software",
    "Edge Computing/Edge-Applications",
    "Green Tech/Sustainable-Computing",
    "Green Tech/Renewable-Energy-Tech",
    "Green Tech/Climate-Tech",
    "Green Tech/Green-IT-Applications",
]

# 전체 경로 조합
emerging_tech_paths = [
    os.path.join(emerging_technologies_path, folder.replace("/", os.sep))
    for folder in emerging_tech_subfolders
]

# 폴더 생성
for path in emerging_tech_paths:
    os.makedirs(path, exist_ok=True)

len(emerging_tech_paths)
# Out:
# 24

# %%
import os

# Frontend 루트 경로
frontend_root = r"D:\blog-data\content\posts2\Frontend"

# Frontend 상위 주요 디렉토리 (파일 구조 요약 반영)
frontend_subfolders = [
    "Fundamentals/HTML/HTML-Basics",
    "Fundamentals/HTML/HTML5-Features",
    "Fundamentals/HTML/Accessibility",
    "Fundamentals/CSS-Basics",
    "Fundamentals/JavaScript-Basics",
    "Fundamentals/Web-APIs",
    "CSS and Styling/CSS-Advanced",
    "CSS and Styling/CSS-Preprocessors",
    "CSS and Styling/CSS-Frameworks",
    "CSS and Styling/CSS-in-JS",
    "Frameworks/React/React-Fundamentals",
    "Frameworks/React/React-Hooks",
    "Frameworks/React/React-Ecosystem",
    "Frameworks/React/React-Advanced",
    "Frameworks/Vue/Vue-Fundamentals",
    "Frameworks/Vue/Vue-Advanced",
    "Frameworks/Vue/Vue-Ecosystem",
    "Frameworks/Angular/Angular-Fundamentals",
    "Frameworks/Angular/Angular-Advanced",
    "Frameworks/Angular/Angular-Ecosystem",
    "Frameworks/Svelte",
    "State Management/Core-Concepts",
    "State Management/Redux",
    "State Management/Context-API",
    "State Management/MobX",
    "State Management/Zustand",
    "State Management/Recoil",
    "State Management/Jotai",
    "Build Tools/Module-Bundlers",
    "Build Tools/Task-Runners",
    "Build Tools/Transpilers",
    "Build Tools/Dev-Tooling",
    "Performance Optimization/Core-Web-Vitals",
    "Performance Optimization/Loading-Optimization",
    "Performance Optimization/Rendering-Optimization",
    "Performance Optimization/Asset-Optimization",
    "Rendering Strategies/Client-Side-Rendering",
    "Rendering Strategies/Server-Side-Rendering",
    "Rendering Strategies/Static-Site-Generation",
    "Rendering Strategies/Hybrid-Approaches",
    "Modern Frontend Architecture/Component-Driven-Development",
    "Modern Frontend Architecture/Micro-Frontends",
    "Modern Frontend Architecture/JAMstack",
    "Modern Frontend Architecture/Frontend-for-Mobile",
    "Progressive Web Apps/PWA-Fundamentals",
    "Progressive Web Apps/PWA-Components",
    "Progressive Web Apps/PWA-Performance",
    "Progressive Web Apps/PWA-Implementation",
    "UI and UX/UI-Design-Principles",
    "UI and UX/UX-Design-Principles",
    "UI and UX/Design-Systems",
    "UI and UX/Accessibility",
    "Web Browser/Browser-Architecture",
    "Web Browser/Browser-APIs",
    "Web Browser/Browser-Extensions",
    "Web Browser/Cross-Browser-Development",
    "WebAssembly/WASM-Fundamentals",
    "WebAssembly/WASM-Development",
    "WebAssembly/WASM-Integration",
    "WebAssembly/WASM-Performance",
]

# 전체 경로 구성
frontend_paths = [
    os.path.join(frontend_root, folder.replace("/", os.sep))
    for folder in frontend_subfolders
]

# 디렉터리 생성
for path in frontend_paths:
    os.makedirs(path, exist_ok=True)

len(frontend_paths)
# Out:
# 60

# %%
# Mobile Development와 Networking 폴더 구조에 기반한 상위 디렉토리 경로 정의

mobile_root = r"D:\blog-data\content\posts2\Mobile Development"
networking_root = r"D:\blog-data\content\posts2\Networking"

# Mobile Development 주요 하위 폴더 경로 정의
mobile_subfolders = [
    "Fundamentals/Mobile-Development-Basics",
    "Fundamentals/UI-UX-for-Mobile",
    "Fundamentals/Mobile-Architecture",
    "Fundamentals/Mobile-App-Lifecycle",
    "Android Development/Android-Fundamentals",
    "Android Development/Android-UI",
    "Android Development/Android-Data",
    "Android Development/Jetpack-Compose",
    "Android Development/Android-Advanced/Background-Processing",
    "Android Development/Android-Advanced/Architecture-Components",
    "Android Development/Android-Advanced/Kotlin-for-Android",
    "iOS Development/iOS-Fundamentals",
    "iOS Development/iOS-UI",
    "iOS Development/iOS-Data",
    "iOS Development/SwiftUI",
    "iOS Development/iOS-Advanced/Concurrency",
    "iOS Development/iOS-Advanced/Swift-Features",
    "iOS Development/iOS-Advanced/iOS-Architecture-Patterns",
    "Cross-Platform Development/React-Native/React-Native-Basics",
    "Cross-Platform Development/React-Native/React-Native-State",
    "Cross-Platform Development/React-Native/React-Native-Native-Modules",
    "Cross-Platform Development/React-Native/React-Native-Performance",
    "Cross-Platform Development/Flutter/Flutter-Basics",
    "Cross-Platform Development/Flutter/Flutter-State",
    "Cross-Platform Development/Flutter/Flutter-UI",
    "Cross-Platform Development/Flutter/Flutter-Advanced",
    "Cross-Platform Development/Xamarin",
    "Cross-Platform Development/Cross-Platform-Comparison",
    "Mobile App Architecture/State-Management",
    "Mobile App Architecture/Dependency-Injection",
    "Mobile App Architecture/Clean-Architecture",
    "Mobile App Architecture/Testing-Architecture",
    "Deployment and Distribution/App-Store-Submission",
    "Deployment and Distribution/Google-Play-Submission",
    "Deployment and Distribution/CI-CD-for-Mobile",
    "Deployment and Distribution/App-Maintenance",
]

# Networking 주요 하위 폴더 경로 정의
networking_subfolders = [
    "Fundamentals/Network-Basics",
    "Fundamentals/Data-Transmission",
    "Fundamentals/Communication-Methods",
    "Fundamentals/Network-Models/OSI-7-Layers",
    "Fundamentals/Network-Models/TCP-IP-4-Layers",
    "Network-Protocols/Application-Layer-Protocols/HTTP",
    "Network-Protocols/Transport-Layer-Protocols/TCP",
    "Network-Protocols/Internet-Layer-Protocols/IP",
    "Network-Protocols/Wireless-Protocols",
    "Network-Infrastructure/Network-Hardware",
    "Network-Infrastructure/Network-Services",
    "Network-Infrastructure/Network-Types",
    "Network-Infrastructure/Network-Traffic",
    "Cloud-Networking/Virtual-Networks",
    "Cloud-Networking/Cloud-Connectivity",
    "Cloud-Networking/Container-Networking",
    "Cloud-Networking/Multi-Cloud-Networking",
    "Network-Security/Fundamentals",
    "Network-Security/Security-Protocols",
    "Network-Security/Network-Security-Devices",
    "Network-Security/Security-Techniques",
    "Modern-Networking/Software-Defined-Networking",
    "Modern-Networking/Network-Functions-Virtualization",
    "Modern-Networking/Intent-Based-Networking",
    "Modern-Networking/Edge-Computing-Networks",
    "Network-Management/Network-Monitoring",
    "Network-Management/Network-Performance",
    "Network-Management/Network-Troubleshooting",
    "Network-Management/Network-Automation",
]

# 전체 경로 생성
mobile_paths = [
    os.path.join(mobile_root, folder.replace("/", os.sep))
    for folder in mobile_subfolders
]
networking_paths = [
    os.path.join(networking_root, folder.replace("/", os.sep))
    for folder in networking_subfolders
]

# 모든 경로 병합 후 디렉토리 생성
all_paths = mobile_paths + networking_paths
for path in all_paths:
    os.makedirs(path, exist_ok=True)

len(all_paths)
# Out:
# 65

# %%
import os

# 루트 경로
prog_lang_root = r"D:\blog-data\content\posts2\Programming Languages"
qa_root = r"D:\blog-data\content\posts2\Quality Assurance"

# 상위 디렉토리 예시 기반 폴더 정의 (트리에서 주요 섹션만 추출하여 구성)
prog_lang_folders = [
    "Fundamentals/Language-Concepts",
    "Fundamentals/Programming-Paradigms",
    "Fundamentals/Type-Systems",
    "Fundamentals/Language-Comparison",
    "Python/Python-Basics/Syntax",
    "Python/Python-Basics/Data-Structures",
    "Python/Python-Basics/Modules-and-Packages",
    "Python/Python-Advanced/Object-Oriented-Python",
    "Python/Python-Advanced/Functional-Features",
    "Python/Python-Advanced/Python-Internals",
    "Python/Python-Advanced/Advanced-Features",
    "Python/Python-Ecosystem/Web-Development",
    "Python/Python-Ecosystem/Data-Science",
    "Python/Python-Ecosystem/DevOps-Tools",
    "Python/Python-Ecosystem/Best-Practices",
    "JavaScript and TypeScript/JavaScript/JavaScript-Basics",
    "JavaScript and TypeScript/JavaScript/JavaScript-Advanced",
    "JavaScript and TypeScript/JavaScript/Modern-JavaScript",
    "JavaScript and TypeScript/TypeScript/TypeScript-Basics",
    "JavaScript and TypeScript/TypeScript/TypeScript-Advanced",
    "JavaScript and TypeScript/TypeScript/TypeScript-Configuration",
    "JavaScript and TypeScript/JavaScript-Ecosystem/Frontend-Frameworks",
    "JavaScript and TypeScript/JavaScript-Ecosystem/Backend",
    "JavaScript and TypeScript/JavaScript-Ecosystem/Build-Tools",
    "Java/Java-Fundamentals/Syntax",
    "Java/Java-Fundamentals/OOP-in-Java",
    "Java/Java-Fundamentals/Java-Collections",
    "Java/Java-Advanced/Concurrency",
    "Java/Java-Advanced/Java-Generics",
    "Java/Java-Advanced/Java-Internals",
    "Java/Java-Ecosystem/Spring-Framework",
    "Java/Java-Ecosystem/Jakarta-EE",
    "Java/Java-Ecosystem/Build-Tools",
    "Go/Go-Basics/Syntax",
    "Go/Go-Basics/Data-Structures",
    "Go/Go-Basics/Packages",
    "Go/Go-Advanced/Concurrency",
    "Go/Go-Advanced/Interfaces",
    "Go/Go-Advanced/Error-Handling",
    "Go/Go-Ecosystem/Web-Development",
    "Go/Go-Ecosystem/DevOps-Tools",
    "Go/Go-Ecosystem/Best-Practices",
    "Kotlin/Kotlin-Basics/Syntax",
    "Kotlin/Kotlin-Basics/Object-Oriented",
    "Kotlin/Kotlin-Basics/Null-Safety",
    "Kotlin/Kotlin-Advanced/Coroutines",
    "Kotlin/Kotlin-Advanced/Functional-Programming",
    "Kotlin/Kotlin-Advanced/Extensions",
    "Kotlin/Kotlin-Ecosystem/Android-Development",
    "Kotlin/Kotlin-Ecosystem/Server-Side",
    "Kotlin/Kotlin-Ecosystem/Kotlin-Multiplatform",
    "Rust/Rust-Basics/Syntax",
    "Rust/Rust-Basics/Ownership",
    "Rust/Rust-Basics/Structs-and-Enums",
    "Rust/Rust-Advanced/Traits",
    "Rust/Rust-Advanced/Concurrency",
    "Rust/Rust-Advanced/Unsafe-Rust",
    "Rust/Rust-Ecosystem/Web-Development",
    "Rust/Rust-Ecosystem/Systems-Programming",
    "Rust/Rust-Ecosystem/Cargo",
]

qa_folders = [
    "Fundamentals/QA-Basics",
    "Fundamentals/Software-Quality",
    "Fundamentals/Testing-Fundamentals",
    "Testing Process/Test-Planning",
    "Testing Process/Test-Design",
    "Testing Process/Test-Execution",
    "Testing Process/Test-Closure",
    "Testing Levels/Unit-Testing",
    "Testing Levels/Integration-Testing",
    "Testing Levels/System-Testing",
    "Testing Levels/Acceptance-Testing",
    "Testing Types/Functional-Testing",
    "Testing Types/Non-Functional-Testing/Performance-Testing",
    "Testing Types/Non-Functional-Testing/Security-Testing",
    "Testing Types/Non-Functional-Testing/Usability-Testing",
    "Testing Types/Non-Functional-Testing/Compatibility-Testing",
    "Testing Types/Specialized-Testing",
    "Testing Approaches/Static-Testing",
    "Testing Approaches/Dynamic-Testing",
    "Testing Approaches/White-Box-Testing",
    "Testing Approaches/Black-Box-Testing",
    "Testing Approaches/Gray-Box-Testing",
    "Testing Approaches/Exploratory-Testing",
    "Test Automation/Automation-Fundamentals",
    "Test Automation/Test-Automation-Frameworks",
    "Test Automation/UI-Automation",
    "Test Automation/API-Automation",
    "Test Automation/CI-CD-Integration",
    "Testing Tools/Test-Management-Tools",
    "Testing Tools/Unit-Testing-Tools",
    "Testing Tools/API-Testing-Tools",
    "Testing Tools/UI-Testing-Tools",
    "Testing Tools/Performance-Testing-Tools",
    "Testing Tools/Security-Testing-Tools",
    "SDLC Integration/Waterfall-QA",
    "SDLC Integration/Agile-Testing",
    "SDLC Integration/DevOps-QA",
    "SDLC Integration/TDD-BDD-ATDD",
    "SDLC Integration/Quality-Engineering",
    "QA Management/QA-Team",
    "QA Management/QA-Metrics",
    "QA Management/Test-Estimation",
    "QA Management/Risk-Based-Testing",
    "Defect Management/Defect-Lifecycle",
    "Defect Management/Root-Cause-Analysis",
    "Defect Management/Defect-Prioritization",
    "Defect Management/Defect-Prevention",
]

# 전체 경로로 변환
prog_lang_paths = [
    os.path.join(prog_lang_root, folder.replace("/", os.sep))
    for folder in prog_lang_folders
]
qa_paths = [os.path.join(qa_root, folder.replace("/", os.sep)) for folder in qa_folders]

# 디렉터리 생성
for path in prog_lang_paths + qa_paths:
    os.makedirs(path, exist_ok=True)

len(prog_lang_paths + qa_paths)
# Out:
# 107

# %%
# 보안(Security) 카테고리 트리에서 주요 폴더 경로 추출 (3~4단계 수준으로 정리)
security_root = r"D:\blog-data\content\posts2\Security"

security_folders = [
    "Fundamentals/Security-Principles",
    "Fundamentals/Threat-Modeling",
    "Fundamentals/Risk-Management",
    "Identity and Access Management/Authentication/Authentication-Methods",
    "Identity and Access Management/Authentication/Authentication-Protocols",
    "Identity and Access Management/Authentication/JWT",
    "Identity and Access Management/Authorization/Authorization-Models",
    "Identity and Access Management/Identity-Providers",
    "Identity and Access Management/Single-Sign-On",
    "Application Security/Secure-Coding",
    "Application Security/SDLC-Security",
    "Application Security/Code-Security",
    "Application Security/Mobile-Security",
    "Application Security/Supply-Chain-Security",
    "Web Security/Client-Side-Security",
    "Web Security/Server-Side-Security",
    "Web Security/API-Security",
    "Web Security/OWASP-Top-10",
    "Network Security/Network-Security-Basics",
    "Network Security/Firewalls",
    "Network Security/IDS-IPS",
    "Network Security/VPN",
    "Network Security/Secure-Protocols/TLS-SSL",
    "Cloud Security/Cloud-Security-Fundamentals",
    "Cloud Security/Cloud-Provider-Security/AWS-Security",
    "Cloud Security/Cloud-Provider-Security/Azure-Security",
    "Cloud Security/Cloud-Provider-Security/GCP-Security",
    "Cloud Security/Container-Security",
    "Cloud Security/Serverless-Security",
    "Cloud Security/Cloud-Security-Posture",
    "Cryptography/Cryptography-Basics",
    "Cryptography/Symmetric-Encryption",
    "Cryptography/Asymmetric-Encryption",
    "Cryptography/Hashing",
    "Cryptography/Public-Key-Infrastructure",
    "Data Security/Data-Protection",
    "Data Security/Database-Security",
    "Data Security/Data-Loss-Prevention",
    "Data Security/Privacy",
    "Security Operations/Security-Monitoring",
    "Security Operations/Incident-Response",
    "Security Operations/Threat-Intelligence",
    "Security Operations/Vulnerability-Management",
    "DevSecOps/SecDevOps-Principles",
    "DevSecOps/Secure-CI-CD",
    "DevSecOps/Infrastructure-Security",
    "DevSecOps/Compliance-as-Code",
    "AI Security/ML-Security-Challenges",
    "AI Security/AI-Privacy",
    "AI Security/Secure-ML-Pipeline",
    "AI Security/LLM-Security",
    "Zero Trust Security/Zero-Trust-Architecture",
    "Zero Trust Security/Micro-Segmentation",
    "Zero Trust Security/Continuous-Verification",
]

# 전체 경로 구성
security_paths = [
    os.path.join(security_root, folder.replace("/", os.sep))
    for folder in security_folders
]

# 폴더 생성
for path in security_paths:
    os.makedirs(path, exist_ok=True)

len(security_paths)
# Out:
# 54

# %%
import os

# 루트 경로 설정
sda_root = r"D:\blog-data\content\posts2\Software Design and Architecture"
sd_root = r"D:\blog-data\content\posts2\System Design"

# Software Design and Architecture 폴더 목록 (중요 경로 기준 요약)
sda_folders = [
    "Fundamentals/Architecture-Basics",
    "Fundamentals/Design-Principles/SOLID",
    "Fundamentals/Design-Principles/Other-Principles",
    "Fundamentals/Design-Principles/Design-Heuristics",
    "Fundamentals/Quality-Attributes",
    "Design Patterns/Pattern-Fundamentals",
    "Design Patterns/Creational-Patterns",
    "Design Patterns/Structural-Patterns",
    "Design Patterns/Behavioral-Patterns",
    "Design Patterns/Architectural-Patterns",
    "Architectural Styles/Monolithic-Architecture",
    "Architectural Styles/Microservices",
    "Architectural Styles/Service-Oriented-Architecture",
    "Architectural Styles/Event-Driven-Architecture",
    "Architectural Styles/Serverless-Architecture",
    "Architectural Styles/Hexagonal-Architecture",
    "Domain-Driven Design/DDD-Fundamentals",
    "Domain-Driven Design/Building-Blocks",
    "Domain-Driven Design/Strategic-Design",
    "Domain-Driven Design/Tactical-Design",
    "Architecture Modeling/UML",
    "Architecture Modeling/C4-Model",
    "Architecture Modeling/Architecture-Description-Languages",
    "Architecture Modeling/Modeling-Tools",
    "Architecture Decision Making/Architectural-Decisions",
    "Architecture Decision Making/Architecture-Evaluation",
    "Architecture Decision Making/Architecture-Decision-Records",
    "Architecture Decision Making/Trade-off-Analysis",
    "Architecture Implementation/Component-Design",
    "Architecture Implementation/API-Design",
    "Architecture Implementation/Data-Architecture",
    "Architecture Implementation/Security-Architecture",
    "Architecture Evolution/Evolutionary-Architecture",
    "Architecture Evolution/Legacy-System-Evolution",
    "Architecture Evolution/Technical-Debt",
    "Architecture Evolution/Architecture-Governance",
    "Modern Architecture Trends/Cloud-Native-Architecture",
    "Modern Architecture Trends/DevOps-Architecture",
    "Modern Architecture Trends/Reactive-Architecture",
    "Modern Architecture Trends/AI-Driven-Architecture",
]

# System Design 폴더 목록
sd_folders = [
    "Fundamentals/System-Design-Basics",
    "Fundamentals/System-Components",
    "Fundamentals/Architectural-Patterns",
    "Scalability/Horizontal-Scaling",
    "Scalability/Vertical-Scaling",
    "Scalability/Database-Scaling",
    "Scalability/Scaling-Patterns",
    "Reliability/Fault-Tolerance",
    "Reliability/Resilience-Patterns",
    "Reliability/Disaster-Recovery",
    "Reliability/Chaos-Engineering",
    "Performance/Latency-Optimization",
    "Performance/Caching-Strategies",
    "Performance/Performance-Measurement",
    "Performance/Concurrency-Models",
    "Data-Management/Data-Storage-Options",
    "Data-Management/Data-Access-Patterns",
    "Data-Management/Data-Consistency",
    "Data-Management/Data-Processing",
    "Communication/Synchronous-Communication",
    "Communication/Asynchronous-Communication",
    "Communication/API-Design",
    "Communication/Service-Mesh",
    "Security/Authentication-Authorization",
    "Security/Data-Security",
    "Security/Network-Security",
    "Security/Security-by-Design",
    "Observability/Logging",
    "Observability/Metrics",
    "Observability/Tracing",
    "Observability/Dashboards",
    "Case-Studies/Web-Applications",
    "Case-Studies/Data-Intensive-Systems",
    "Case-Studies/Distributed-Systems",
    "Case-Studies/Real-time-Systems",
    "Cloud-Native-Design/Containerization",
    "Cloud-Native-Design/Serverless-Architecture",
    "Cloud-Native-Design/Infrastructure-as-Code",
    "Cloud-Native-Design/Cloud-Deployment-Models",
    "Design-Methodology/Requirements-Gathering",
    "Design-Methodology/System-Design-Interview",
    "Design-Methodology/Documentation",
    "Design-Methodology/System-Design-Process",
]

# 전체 경로 생성
sda_paths = [
    os.path.join(sda_root, folder.replace("/", os.sep)) for folder in sda_folders
]
sd_paths = [os.path.join(sd_root, folder.replace("/", os.sep)) for folder in sd_folders]

# 폴더 생성
for path in sda_paths + sd_paths:
    os.makedirs(path, exist_ok=True)

len(sda_paths + sd_paths)
# Out:
# 83
