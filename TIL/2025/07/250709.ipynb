# %%
from datetime import datetime

# %%
import pytz


def to_kst(dt):
    return pytz.timezone("Asia/Seoul").localize(dt)

# %%
to_kst(target_date)
# Out:
# datetime.datetime(2025, 7, 9, 17, 34, 59, 605825, tzinfo=<DstTzInfo 'Asia/Seoul' KST+9:00:00 STD>)

# %%
app_id = 1
campaign_id = 3
event_type = "event"
target_date = datetime.now()

# %%
key = "stats:app:{app_id}:campaign:{campaign_id}:event_type:{event_type}:date:{date}:hour:{hour}".format(
    app_id=app_id,
    campaign_id=campaign_id,
    event_type=event_type,
    date=target_date.strftime("%Y-%m-%d"),
    hour=target_date.strftime("%H"),
)

# %%
int(-1)
# Out:
# -1

# %%
app_id = None

# %%
app_id

# %%
tracker_name = ""
app_id = 1
campaign_id = 3
user_id = 1234567890

# %%
if not app_id or not campaign_id or not user_id or not tracker_name:
    print("a")
# Out:
# a
