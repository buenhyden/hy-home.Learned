# %%
import urllib.request
import json

client_id = "qR7ty7ZP6XMG1eZHf7Xo"
client_secret = "9YiRUq1cV5"
url = "https://openapi.naver.com/v1/datalab/search"
body = {
    "startDate": "2017-01-01",
    "endDate": "2017-04-30",
    "timeUnit": "month",
    "keywordGroups": [
        {"groupName": "한글", "keywords": ["한글", "korean"]},
        {"groupName": "영어", "keywords": ["영어", "english"]},
    ],
    "device": "pc",
    "ages": ["1", "2"],
    "gender": "f",
}
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id", client_id)
request.add_header("X-Naver-Client-Secret", client_secret)
request.add_header("Content-Type", "application/json")
response = urllib.request.urlopen(request, data=json.dumps(body).encode("utf-8"))
rescode = response.getcode()
if rescode == 200:
    response_body = response.read()
    print(response_body.decode("utf-8"))
else:
    print("Error Code:" + rescode)
# Out:
# {"startDate":"2017-01-01","endDate":"2017-04-30","timeUnit":"month","results":[{"title":"한글","keywords":["한글","korean"],"data":[{"period":"2017-01-01","ratio":47.00101},{"period":"2017-02-01","ratio":53.23619},{"period":"2017-03-01","ratio":100},{"period":"2017-04-01","ratio":85.327}]},{"title":"영어","keywords":["영어","english"],"data":[{"period":"2017-01-01","ratio":40.0881},{"period":"2017-02-01","ratio":36.69942},{"period":"2017-03-01","ratio":52.11792},{"period":"2017-04-01","ratio":44.4595}]}]}

# %%
import requests
from bs4 import BeautifulSoup

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request

client_id = "qR7ty7ZP6XMG1eZHf7Xo"
client_secret = "9YiRUq1cV5"
encText = urllib.parse.quote("검색할 단어")
display_count = 20
start = 1
sort = "sim"
url = f"https://openapi.naver.com/v1/search/news.json?query={encText}&display={display_count}&start={start}&sort={sort}"  # JSON 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id", client_id)
request.add_header("X-Naver-Client-Secret", client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if rescode == 200:
    response_body = response.read()
    # print(response_body.decode("utf-8"))
else:
    print("Error Code:" + rescode)

# %%
response_body_decode = response_body.decode("utf-8")

# %%
json.loads(response_body_decode)
# Out:
# {'lastBuildDate': 'Tue, 25 Nov 2025 13:02:41 +0900',
#  'total': 95004,
#  'start': 1,
#  'display': 20,
#  'items': [{'title': '창업하자 350억 모였다… “같은 비용으로 AI <b>검색</b> 성능 10배”[허진석의...',
#    'originallink': 'https://www.donga.com/news/It/article/all/20251121/132818089/2',
#    'link': 'https://n.news.naver.com/mnews/article/020/0003676316?sid=105',
#    'description': '2023년 3월에 나온 오픈AI의 GPT4와 빙 <b>검색</b>이 결합된 마이크로소프트 코파일럿이 시초로 꼽힌다. 이전에는... ● “AI 시대, 벡터 기반 데이터 처리가 관건” 컴퓨터는 <b>단어</b>나 이미지를 그대로 이해하지 못한다. 그래서... ',
#    'pubDate': 'Sat, 22 Nov 2025 01:43:00 +0900'},
#   {'title': "네이버 'AI 키워드 <b>검색</b>' 첫 도입…스포츠·연예 우선 적용",
#    'originallink': 'https://www.yna.co.kr/view/AKR20251119107000017?input=1195m',
#    'link': 'https://n.news.naver.com/mnews/article/001/0015751645?sid=105',
#    'description': "AI <b>검색</b>' 기능을 도입해 운영 중인 것으로 확인됐다. 19일 네이버에 따르면 네이버는 지난 13일부터 AI 기술을... 해당 <b>단어</b>가 파란색 글씨로 뜨고, 그 <b>단어</b>를 클릭하면 하이퍼링크를 통해 관련 내용을 소개해주는 사이트로... ",
# ...
