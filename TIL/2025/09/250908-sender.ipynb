# %%
import socket, struct, time

MCAST_GRP = "239.1.1.1"
MCAST_PORT = 5007
TTL = 2  # 멀티캐스트 범위를 로컬 세그먼트로 제한

sock = socket.socket(socket.AF_INET, socket.SOCK_DGRAM, socket.IPPROTO_UDP)
# TTL 설정
sock.setsockopt(socket.IPPROTO_IP, socket.IP_MULTICAST_TTL, TTL)
# 루프백 허용(동일 호스트 수신 확인)
sock.setsockopt(socket.IPPROTO_IP, socket.IP_MULTICAST_LOOP, 1)

for i in range(1, 11):
    msg = f"multicast message {i}"
    sock.sendto(msg.encode(), (MCAST_GRP, MCAST_PORT))
    print("Sent:", msg)
    time.sleep(1)
# Out:
# Sent: multicast message 1
# Sent: multicast message 2
# Sent: multicast message 3
# Sent: multicast message 4
# Sent: multicast message 5
# Sent: multicast message 6
# Sent: multicast message 7
# Sent: multicast message 8
# Sent: multicast message 9
# Sent: multicast message 10
